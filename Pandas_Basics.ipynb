# %% [markdown]
# <a href="https://colab.research.google.com/github/Bornitaadhikari/My-Projects/blob/main/Pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
mydata={
    "Car":['BMW','VOlVo','Ford'],
    "passings":[789,907,907]                      #create Datafeame
}
mydf=pandas.DataFrame(mydata)
mydf
# Out:
#      Car  passings
# 0    BMW       789
# 1  VOlVo       907
# 2   Ford       907

# %%
import pandas as pd

# %%
mydata={
    "Car":['BMW','VOlVo','Ford'],
    "passings":[789,907,907]
}
mydf=pd.DataFrame(mydata)
mydf
# Out:
#      Car  passings
# 0    BMW       789
# 1  VOlVo       907
# 2   Ford       907

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
a=[2,3,4]
mys=pd.Series(a)           #Pandas series
mys
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64

# %%
a=[1,7,9]
mys=pd.Series(a,index=["a","b","c"])   #create lebels
mys
# Out:
# a    1
# b    7
# c    9
# dtype: int64

# %%
a=[4000,5000,6000]
mys=pd.Series(a,index=["v","b","c"])
mys
# Out:
# v    4000
# b    5000
# c    6000
# dtype: int64

# %%
calories={"day1":67809,"day2":1234,"day3":7889}  #values object as series
mys=pd.Series(calories)
mys
# Out:
# day1    67809
# day2     1234
# day3     7889
# dtype: int64

# %%
data={
    "fruits":[789,890,890,344],     #DataFrame
    "Numbers":[234,455,656,678]
}
mys=pd.DataFrame(data)
mys
# Out:
#    fruits  Numbers
# 0     789      234
# 1     890      455
# 2     890      656
# 3     344      678

# %%
mys.loc[2]
# Out:
# fruits     890
# Numbers    656
# Name: 2, dtype: int64

# %%
mys.loc[[2,3]]
# Out:
#    fruits  Numbers
# 2     890      656
# 3     344      678

# %%
mydata={
    "Car":['BMW','VOlVo','Ford'],
    "passings":[789,907,907]
}
mydf=pd.DataFrame(mydata,index=["day1","day2","day3"])
mydf
# Out:
#         Car  passings
# day1    BMW       789
# day2  VOlVo       907
# day3   Ford       907

# %%
mydf.iloc[0]
# Out:
# Car         BMW
# passings    789
# Name: day1, dtype: object

# %%
mydf.loc['day1']
# Out:
# Car         BMW
# passings    789
# Name: day1, dtype: object

# %%
df=pd.read_csv('/content/data2.csv')   #read csv
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
pd.options.display.max_rows=200 #set the data visiable limit

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %% [markdown]
# Cleaning Empty Rows

# %%
df.isna().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
ndf=df.dropna()
ndf.isna().sum()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df=pd.read_csv('/content/data2.csv')   #read csv
df

# %%
df3=df.fillna(0)
df3

# %%
df3.isna().sum()
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %% [markdown]
# Replacing Null Values with mean, median,mode

# %%
df["Calories"].fillna(130)

# %%
x=df["Calories"].mean()
x
# Out:
# 304.68

# %%
df["Calories"].fillna(x)

# %%
df2=pd.read_csv('/content/data2.csv')   #read csv
df2
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
pd.to_datetime(df2['Date'])
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 18   2020-12-18
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 22          NaT
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 28   2020-12-28
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# Remove duplicated values

# %%
df.duplicated()

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool
